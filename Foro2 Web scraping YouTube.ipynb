# %% [markdown]
# # Web scraping YouTube

# %% [markdown]
# * Alumna: Alexandra Moran Baygorrea
#
# ### 1. Crearse una cuenta en:
# [Google Cloud Platform](https://console.cloud.google.com/)
#
# ### 2. Pasos para obtener Api Key:
# - Crear un proyecto
# - Ir a **Library**, elegir la API con nombre: **Youtube Data API v3** y darle click en habilitar (enable).
# - Ir a **Credientals**, click en *+ CREATE CREDENTIALS* > *API key* y listo ya tienes tu clave.

# %% [markdown]
# En este proyecto se extraeré detalles del canales de youtube como el nombre del canal, número total de suscriptores, vistas y videos publicados por el canal mediante la creación de una función. Luego compararé estos datos de los canales entre sí. Luego se cargará todos estos datos en un marco de datos de pandas para su analisis. También se producirá una visualización básica usando estos datos para que podamos comparar fácilmente los canales elegidos.
#
# #### Documentos a usar:
# [Documentación API de datos de Google YouTube](https://developers.google.com/youtube/v3)

# %%
#instalar los siguientes paquetes:
pip install --upgrade google-api-python-client
# Out:
# Collecting google-api-python-clientNote: you may need to restart the kernel to use updated packages.
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'Se ha forzado la interrupción de una conexión existente por el host remoto', None, 10054, None))': /packages/35/ee/718edb95cecc1686fac2afb2631f9f592690a12e13ea5b546db860ad489d/google_api_python_client-2.37.0-py2.py3-none-any.whl
#   Downloading google_api_python_client-2.37.0-py2.py3-none-any.whl (8.1 MB)
# Collecting httplib2<1dev,>=0.15.0
#   Downloading httplib2-0.20.4-py3-none-any.whl (96 kB)
# Collecting uritemplate<5,>=3.0.1
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Collecting google-auth<3.0.0dev,>=1.16.0
#   Downloading google_auth-2.6.0-py2.py3-none-any.whl (156 kB)
# Collecting google-api-core<3.0.0dev,>=1.21.0
#   Downloading google_api_core-2.5.0-py2.py3-none-any.whl (111 kB)
# Collecting google-auth-httplib2>=0.1.0
#   Downloading google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in c:\users\user\anaconda3\lib\site-packages (from google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (2.27.1)
# Collecting googleapis-common-protos<2.0dev,>=1.52.0
#   Downloading googleapis_common_protos-1.54.0-py2.py3-none-any.whl (207 kB)
# Collecting protobuf>=3.12.0
#   Downloading protobuf-3.19.4-cp39-cp39-win_amd64.whl (895 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.0.0-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: six>=1.9.0 in c:\users\user\anaconda3\lib\site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (1.16.0)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\users\user\anaconda3\lib\site-packages (from httplib2<1dev,>=0.15.0->google-api-python-client) (3.0.4)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (3.2)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core<3.0.0dev,>=1.21.0->google-api-python-client) (2021.10.8)
# Installing collected packages: pyasn1, rsa, pyasn1-modules, protobuf, cachetools, httplib2, googleapis-common-protos, google-auth, uritemplate, google-auth-httplib2, google-api-core, google-api-python-client
# Successfully installed cachetools-5.0.0 google-api-core-2.5.0 google-api-python-client-2.37.0 google-auth-2.6.0 google-auth-httplib2-0.1.0 googleapis-common-protos-1.54.0 httplib2-0.20.4 protobuf-3.19.4 pyasn1-0.4.8 pyasn1-modules-0.2.8 rsa-4.8 uritemplate-4.1.1

# %%
# Librerias que se van a usar:
from googleapiclient.discovery import build
import pandas as pd

# %% [markdown]
# ## Función para obtener datos estadísticos de un canal

# %%
#Guardamos nuestra clave en api_key:
api_key = "AIzaSyB5qBiTCi15ye4lW_2c-W_c-pEaYp84Oi8" #propia
#Guardamos la identificación propia del canal a analizar:
canal_id="UCy5FUarBYUHFpPtYVuvzgcA" #Canal de Zayn Malik
#Para obtener el servicio de youtube: servidor/versión/clave
youtube=build("youtube","v3",developerKey=api_key)

# %%
#Creamos una función que extraiga las estadísticas del canal:
def info_canal(youtube, canal_id):
#Solicitamos una colección del canal mediante el parámetro part con los siguientes argumentos:
#snippet: información básica del canal, como título, descripción,imágenes en miniatura
#statistics: contiene estadísticas del canal.
    request = youtube.channels().list(
                part="snippet,statistics",
                id=canal_id)
    response=request.execute()
#Creamos un diccionario para guardar los datos de interés:
    data=dict(Nombre_canal=response["items"][0]["snippet"]["title"],
              Suscriptores=response["items"][0]["statistics"]['subscriberCount'],
              Views=response["items"][0]["statistics"]['viewCount'],
              Total_videos=response["items"][0]["statistics"]['videoCount'])
    
#Si ejecutamos la función return response en vez de return data tendremos toda la información de los tres parámetros pedidos.
    #return response 
#Pero ejecutamos return data ya que solo queremos los datos pedidos   
    return data

# %%
# Usando la función:
info_canal(youtube, canal_id)
#Obtenemos un diccionario, con los datos solicitados.
# Out:
# {'Nombre_canal': 'ZaynVEVO',
#  'Suscriptores': '5950000',
#  'Views': '4014292519',
#  'Total_videos': '90'}

# %% [markdown]
# ## Función para obtener datos estadísticos de varios canales a la vez
# En este caso solo se modificará la función anterior:

# %%
#Guardamos las identificaiones de los canales a analizar:
canales_ids=["UCy5FUarBYUHFpPtYVuvzgcA", #Zayn Malik 
             "UCbOCbp5gXL8jigIBZLqMPrw", #Harry Styles 
             "UCZIrDb4j3_dJf3G9jROboZQ", #Liam Payne
             "UCR5BwOS3Gb4uQtxRYRUQ7ng", #Louis Tomlinson
             "UCPrwhIldj47n8JcqZ4Y_WFQ"] #Niall Horan

# %%
def info_canales(youtube, canales_ids):
    lista=[] #lista vacía para luego almacenar los datos
    request = youtube.channels().list(
                part="snippet,statistics,contentDetails",
                id=",".join(canales_ids))
    response=request.execute()
    #Para que recorra todas los canales_ids:
    for i in range(len(response["items"])):
        data=dict(Nombre_canal=response["items"][i]["snippet"]["title"],
                  Suscriptores=response["items"][i]["statistics"]['subscriberCount'],
                  Views=response["items"][i]["statistics"]['viewCount'],
                  Total_videos=response["items"][i]["statistics"]['videoCount'],
                  Playlist_id=response["items"][i]["contentDetails"]["relatedPlaylists"]["uploads"])
        #Se guarda el diccionario en una lista:
        lista.append(data)
    #return response
    return lista

# %%
#Se usa la función para extraer los datos de lista:
#info_canales(youtube, canales_ids)
channel_statistics=info_canales(youtube, canales_ids)
#Conversión a Data Frame
channel_data=pd.DataFrame(channel_statistics)
channel_data
# Out:
#          Nombre_canal Suscriptores       Views Total_videos  \
# 0     HarryStylesVEVO      3110000  2984913552           38
# 1            ZaynVEVO      5950000  4014292519           90
# 2       LiamPayneVEVO      1540000   749153938           46
# 3      NiallHoranVEVO      2170000   739073905           59
# 4  LouisTomlinsonVEVO      1520000   669918017           21
#
#                 Playlist_id
# 0  UUbOCbp5gXL8jigIBZLqMPrw
# 1  UUy5FUarBYUHFpPtYVuvzgcA
# 2  UUZIrDb4j3_dJf3G9jROboZQ
# 3  UUPrwhIldj47n8JcqZ4Y_WFQ
# 4  UUR5BwOS3Gb4uQtxRYRUQ7ng

# %% [markdown]
# ## Función para obtener la lista completa de videos

# %%
#Como ejemplo se toma al canal "Zayn VEVO", si se quisiera de otro cantante del DataFrame, reeemplazar el nombre.
playlist=channel_data.loc[channel_data["Nombre_canal"]=="ZaynVEVO", "Playlist_id"].iloc[0]

# %%
def videos_id (youtube, Playlist_id):
    request=youtube.playlistItems().list(
                    part="contentDetails",
                    playlistId=playlist,
                    maxResults=50)
    response=request.execute()
  
    videos=[]
    for i in range(len(response["items"])):
        videos.append(response["items"][i]["contentDetails"]["videoId"])
        
#Nota:los resultados por página solo muestran 50 videos, por eso se hace la siguiente iteración, para capturar todos los videos.
# para eso se usa el parámetro "nextPageToken"     
    token_pagina=response.get("nextPageToken")
    mas_paginas=True
    
    while mas_paginas:
        if token_pagina is None:
            mas_paginas=False
        else:
            request=youtube.playlistItems().list(
                    part="contentDetails",
                    playlistId=playlist,
                    maxResults=50,
                    pageToken=token_pagina)
            response=request.execute()
            
            for i in range(len(response["items"])):
                videos.append(response["items"][i]["contentDetails"]["videoId"])
            
            token_pagina=response.get("nextPageToken")
    
    return videos
    #return len(videos)

# %%
#videos_id(youtube, canales_ids)
videos_id=videos_id(youtube, canales_ids)
print(videos_id)
# Out:
# ['KPe0e5EEKSw', 'rtLB9wBwCXs', 'eF_kC8LxtLw', 'y3kTdkyb7vg', 'jQEjeVPTWe0', '8t7aJ571wik', 'wg3_S3BIyDQ', '7sKCGvLMxrU', 'ADw3m4UhYak', 'Hybr_oBNRQE', '5WX_vICMBu8', 'GWQlGKwmb5E', 'lMKxLeBaQbU', '_QzFnZ5oyTw', 'ski6cXdYH5o', 'QqPOneQgvwc', 't_dVQqvZeKM', 'daJgg8o0aNA', 'BiSXG8EgQOA', '75EYy4cI4_U', '-nA6j3a10X8', 'VSpgaN3wuag', 'NAo38Q9c4xA', '033499WBFTM', '5yj9ZbsYef8', 'r2zyYAClv1g', 'LPuCMuoveQ8', 'Y-djQx9GJ2E', '54wX7AvU0_8', 'C283J_HDZuk', 'jZlS32MMsBQ', '2y2Ctg3y3bk', '6zWpkFiYrrI', 'F7Xm8tdH7PY', '8i-l13ek_DQ', 'uYx01hHNtn4', 'EzyMnn4lBG8', 'PwNVRUJvMV0', '6tynVGicBQU', 'v2Fc9ud5T4k', 'ocqDWzJxu9U', 'ap1jann73iQ', 'DxX37fyx_58', 'FPuTzmhR-4o', 'eFsGA0GXB-8', 'EB32NhsQGJA', '9cmPcH38wjc', 'X6QVOtow798', 'XkZz8hodDn0', 'voG07pt-KYI', 'zF9Zl7sAzS0', 'mdeg4fX4RJ0', 'wkLDQJ7jvi8', 'FwOX2kfZyvI', 'ahQ3q9G8Oqk', 'go8_ZWFdYGs', 'lf7eQ2PksA8', '-HWAsjirC90', '-R61rLBsGhY', '85202y7i4_w', 'TFWTU00mq8k', 'YpJ5QMqHR_E', 'eEa5-G3H788', 'FLaAOHv3qCY', 'J-dv_DcDD_A', 'tt2k8PGm-TI', 'shHeDYCirNU', 'cHOrHGpL4u0', 'K4ZeDuKF4m8', 'VLfnMVrG_-w', 'AY9blLYMKnI', 'PAlb8rX3IS8', 'zbdmHYVupDE', '6mfVv9YTgTM', 'BAp41EhApqc', 'CQUZWsNXwT0', 'qlhWEkRNKHw', 'DCXagBKi7Dk', 'pTaqcGz2O5o', 'DhjzqMqZXUc', '7aPDuU3j8-c', 'ChADDD8C16U', '1seDBXvGYcc', '_EaPxw5exts', 'FIrXpp_Nlt4', 'iqLzjlA2hYw', 'C_cj3E61WO8', '2hffbFKHJS4', 'YLc0dMaLyT0', 'C_3d6GntKbk']

# %%
#Utilizando la función anterior para obtener la lista:
def detalles_video(youtube,videos_id):
    Total_videos=[]
    
    for i in range(0,len(videos_id),50):
        request=youtube.videos().list(
                part="snippet,statistics",
                id=",".join(videos_id[i:i+50]))
        response=request.execute()
        
        for video in response["items"]:
            video_stats=dict(Titulo=video["snippet"]["title"],
                             Public=video["snippet"]["publishedAt"],
                             Views=video["statistics"]["viewCount"],
                             Likes=video["statistics"]["likeCount"],
                             Comentarios=video["statistics"]["commentCount"])
            
            Total_videos.append(video_stats)
    
    return Total_videos

# %%
#Vemos los resulltados:
detalles_video(youtube,videos_id)
# Out:
# [{'Titulo': 'ZAYN - "River Road" (Comic 11)',
#   'Public': '2021-03-11T17:00:17Z',
#   'Views': '953156',
#   'Likes': '62810',
#   'Comentarios': '3836'},
#  {'Titulo': 'ZAYN - "Tightrope" (Comic 10)',
#   'Public': '2021-03-04T17:00:19Z',
#   'Views': '530981',
#   'Likes': '50278',
#   'Comentarios': '3033'},
#  {'Titulo': 'ZAYN - "Windowsill" feat. Devlin (Comic 9)',
#   'Public': '2021-03-04T17:00:14Z',
#   'Views': '181081',
#   'Likes': '30499',
#   'Comentarios': '1988'},
#  {'Titulo': 'ZAYN - "Unf**kwitable" (Comic 8)',
#   'Public': '2021-02-25T17:00:22Z',
#   'Views': '258360',
#   'Likes': '46713',
#   'Comentarios': '3412'},
#  {'Titulo': 'ZAYN - "Sweat" (Comic 7)',
#   'Public': '2021-02-11T17:00:30Z',
#   'Views': '371807',
#   'Likes': '49006',
#   'Comentarios': '3068'},
#  {'Titulo': 'ZAYN - "When Love\'s Around" feat. Syd (Comic 6)',
#   'Public': '2021-02-11T17:00:03Z',
#   'Views': '225771',
#   'Likes': '36657',
#   'Comentarios': '2623'},
#  {'Titulo': 'ZAYN - "Connexion" (Comic 5)',
#   'Public': '2021-02-04T17:00:19Z',
#   'Views': '278247',
#   'Likes': '52495',
#   'Comentarios': '3105'},
#  {'Titulo': 'ZAYN - "Vibez" (Comic 4)',
#   'Public': '2021-01-28T17:00:10Z',
#   'Views': '415851',
#   'Likes': '61716',
#   'Comentarios': '3077'},
#  {'Titulo': 'ZAYN - "Outside" (Comic 3)',
#   'Public': '2021-01-28T17:00:09Z',
#   'Views': '474828',
#   'Likes': '67872',
#   'Comentarios': '3755'},
#  {'Titulo': 'ZAYN - Vibez (Behind The Scenes)',
#   'Public': '2021-01-25T17:00:08Z',
#   'Views': '1061303',
#   'Likes': '170316',
#   'Comentarios': '8630'},
#  {'Titulo': 'ZAYN - "Better" (Comic 2)',
#   'Public': '2021-01-21T17:00:05Z',
#   'Views': '659708',
#   'Likes': '125991',
#   'Comentarios': '7083'},
#  {'Titulo': 'ZAYN - "Calamity" (Comic 1)',
#   'Public': '2021-01-21T17:00:05Z',
#   'Views': '728096',
#   'Likes': '138009',
#   'Comentarios': '8190'},
#  {'Titulo': 'ZAYN - Outside (Audio)',
#   'Public': '2021-01-15T05:00:30Z',
#   'Views': '4555056',
#   'Likes': '197974',
#   'Comentarios': '9890'},
#  {'Titulo': 'ZAYN - Calamity (Audio)',
#   'Public': '2021-01-15T05:00:26Z',
#   'Views': '2356662',
#   'Likes': '145975',
#   'Comentarios': '6756'},
#  {'Titulo': 'ZAYN - Unfuckwitable (Audio)',
#   'Public': '2021-01-15T05:00:22Z',
#   'Views': '1385570',
#   'Likes': '99664',
#   'Comentarios': '4328'},
#  {'Titulo': 'ZAYN - Windowsill (Audio) ft. Devlin',
#   'Public': '2021-01-15T05:00:13Z',
#   'Views': '1725143',
#   'Likes': '100155',
#   'Comentarios': '4364'},
#  {'Titulo': 'ZAYN - Connexion (Audio)',
#   'Public': '2021-01-15T05:00:10Z',
#   'Views': '1803462',
#   'Likes': '98469',
#   'Comentarios': '4156'},
#  {'Titulo': "ZAYN - When Love's Around (Audio) ft. Syd",
#   'Public': '2021-01-15T05:00:07Z',
#   'Views': '2044802',
#   'Likes': '111276',
#   'Comentarios': '3958'},
#  {'Titulo': 'ZAYN - Sweat (Audio)',
#   'Public': '2021-01-15T05:00:05Z',
#   'Views': '5333981',
#   'Likes': '184656',
#   'Comentarios': '8565'},
#  {'Titulo': 'ZAYN - Tightrope (Audio)',
#   'Public': '2021-01-15T05:00:02Z',
#   'Views': '5609702',
#   'Likes': '247270',
#   'Comentarios': '16935'},
#  {'Titulo': 'ZAYN - River Road (Audio)',
#   'Public': '2021-01-15T05:00:01Z',
#   'Views': '1822452',
#   'Likes': '124770',
#   'Comentarios': '7718'},
#  {'Titulo': 'ZAYN - Vibez (Official Video)',
#   'Public': '2021-01-08T17:00:08Z',
#   'Views': '35874557',
#   'Likes': '1390384',
#   'Comentarios': '88888'},
#  {'Titulo': 'ZAYN - Better (Official Video)',
#   'Public': '2020-09-25T04:00:10Z',
#   'Views': '39840240',
#   'Likes': '1676980',
#   'Comentarios': '197944'},
#  {'Titulo': 'ZAYN - Sour Diesel',
#   'Public': '2019-04-18T16:44:09Z',
#   'Views': '6198752',
#   'Likes': '303758',
#   'Comentarios': '13996'},
#  {'Titulo': 'ZAYN - Stand Still (Official Video)',
#   'Public': '2019-04-15T04:00:00Z',
#   'Views': '6069358',
#   'Likes': '325463',
#   'Comentarios': '13158'},
#  {'Titulo': 'ZAYN - Satisfaction (Official Video)',
#   'Public': '2019-01-09T16:58:15Z',
#   'Views': '10284112',
#   'Likes': '480182',
#   'Comentarios': '21548'},
#  {'Titulo': 'ZAYN - Insomnia (Audio)',
#   'Public': '2018-12-21T05:00:05Z',
#   'Views': '2550590',
#   'Likes': '75285',
#   'Comentarios': '2330'},
#  {'Titulo': 'ZAYN - If I Got You (Audio)',
#   'Public': '2018-12-21T05:00:05Z',
#   'Views': '2114109',
#   'Likes': '56746',
#   'Comentarios': '1598'},
#  {'Titulo': 'ZAYN - Flight Of The Stars (Audio)',
#   'Public': '2018-12-21T05:00:02Z',
#   'Views': '2335836',
#   'Likes': '60976',
#   'Comentarios': '1868'},
#  {'Titulo': 'ZAYN - Fresh Air (Audio)',
#   'Public': '2018-12-21T05:00:02Z',
#   'Views': '1055724',
#   'Likes': '40751',
#   'Comentarios': '1239'},
#  {'Titulo': 'ZAYN - All That (Audio)',
#   'Public': '2018-12-21T05:00:02Z',
#   'Views': '1134237',
#   'Likes': '34940',
#   'Comentarios': '1056'},
#  {'Titulo': 'ZAYN - Talk To Me (Audio)',
#   'Public': '2018-12-21T05:00:00Z',
#   'Views': '2039238',
#   'Likes': '61673',
#   'Comentarios': '2132'},
#  {'Titulo': 'ZAYN - Icarus Interlude (Audio)',
#   'Public': '2018-12-21T05:00:00Z',
#   'Views': '1082896',
#   'Likes': '32731',
#   'Comentarios': '1075'},
#  {'Titulo': "ZAYN - I Don't Mind (Audio)",
#   'Public': '2018-12-21T05:00:00Z',
#   'Views': '1396531',
#   'Likes': '43980',
#   'Comentarios': '1450'},
#  {'Titulo': 'ZAYN - Stand Still (Audio)',
#   'Public': '2018-12-14T15:27:14Z',
#   'Views': '1081987',
#   'Likes': '37199',
#   'Comentarios': '1437'},
#  {'Titulo': 'ZAYN - Natural (Audio)',
#   'Public': '2018-12-14T14:42:36Z',
#   'Views': '3304148',
#   'Likes': '78120',
#   'Comentarios': '2333'},
#  {'Titulo': 'ZAYN - Imprint (Audio)',
#   'Public': '2018-12-14T14:39:55Z',
#   'Views': '2510087',
#   'Likes': '60781',
#   'Comentarios': '1904'},
#  {'Titulo': 'ZAYN - Scripted (Audio)',
#   'Public': '2018-12-14T14:37:38Z',
#   'Views': '2037055',
#   'Likes': '60530',
#   'Comentarios': '2795'},
#  {'Titulo': 'ZAYN - Tonight (Audio)',
#   'Public': '2018-12-14T14:36:23Z',
#   'Views': '7695499',
#   'Likes': '144719',
#   'Comentarios': '4595'},
#  {'Titulo': 'ZAYN - Back To Life (Audio)',
#   'Public': '2018-12-14T05:00:09Z',
#   'Views': '5952214',
#   'Likes': '133618',
#   'Comentarios': '4661'},
#  {'Titulo': 'ZAYN - Satisfaction (Audio)',
#   'Public': '2018-12-14T05:00:03Z',
#   'Views': '1912894',
#   'Likes': '63174',
#   'Comentarios': '2695'},
#  {'Titulo': 'ZAYN - Good Guy (Audio)',
#   'Public': '2018-12-14T05:00:01Z',
#   'Views': '1657807',
#   'Likes': '61860',
#   'Comentarios': '2913'},
#  {'Titulo': 'ZAYN - You Wish You Knew (Audio)',
#   'Public': '2018-12-14T05:00:00Z',
#   'Views': '2517223',
#   'Likes': '75552',
#   'Comentarios': '2450'},
#  {'Titulo': 'ZAYN - Common (Audio)',
#   'Public': '2018-12-14T05:00:00Z',
#   'Views': '7371160',
#   'Likes': '179419',
#   'Comentarios': '5966'},
#  {'Titulo': 'ZAYN - There You Are (Lyric Video)',
#   'Public': '2018-12-11T17:00:05Z',
#   'Views': '17149514',
#   'Likes': '410044',
#   'Comentarios': '19903'},
#  {'Titulo': 'ZAYN - Good Years (Audio)',
#   'Public': '2018-12-06T13:00:02Z',
#   'Views': '14146241',
#   'Likes': '466903',
#   'Comentarios': '27631'},
#  {'Titulo': 'ZAYN - Fingers (Audio)',
#   'Public': '2018-10-18T12:00:01Z',
#   'Views': '16570354',
#   'Likes': '362540',
#   'Comentarios': '19503'},
#  {'Titulo': 'ZAYN - Too Much ft. Timbaland',
#   'Public': '2018-08-02T12:00:02Z',
#   'Views': '14145417',
#   'Likes': '303441',
#   'Comentarios': '18005'},
#  {'Titulo': 'ZAYN - Sour Diesel (Audio)',
#   'Public': '2018-07-18T16:00:03Z',
#   'Views': '4907495',
#   'Likes': '163742',
#   'Comentarios': '11487'},
#  {'Titulo': 'ZAYN - Entertainer (Official Video)',
#   'Public': '2018-05-23T16:00:03Z',
#   'Views': '85704068',
#   'Likes': '1199013',
#   'Comentarios': '48575'},
#  {'Titulo': 'ZAYN - dRuNk (Lyric Video)',
#   'Public': '2018-05-06T07:00:08Z',
#   'Views': '5831824',
#   'Likes': '102597',
#   'Comentarios': '2809'},
#  {'Titulo': 'ZAYN - lUcOzAdE (Lyric Video)',
#   'Public': '2018-05-06T07:00:05Z',
#   'Views': '2044451',
#   'Likes': '44528',
#   'Comentarios': '1562'},
#  {'Titulo': 'ZAYN - BoRdErSz (Lyric Video)',
#   'Public': '2018-05-06T07:00:05Z',
#   'Views': '4115253',
#   'Likes': '71619',
#   'Comentarios': '2114'},
#  {'Titulo': 'ZAYN - INTERMISSION: fLoWer (Lyric Video)',
#   'Public': '2018-05-06T07:00:03Z',
#   'Views': '869204',
#   'Likes': '41609',
#   'Comentarios': '2601'},
#  {'Titulo': 'ZAYN - BLUE (Lyric Video)',
#   'Public': '2018-05-06T07:00:02Z',
#   'Views': '2845599',
#   'Likes': '43224',
#   'Comentarios': '1978'},
#  {'Titulo': 'ZAYN - MiNd Of MiNdd (Intro) (Lyric Video)',
#   'Public': '2018-05-06T07:00:02Z',
#   'Views': '1817244',
#   'Likes': '41161',
#   'Comentarios': '848'},
#  {'Titulo': 'ZAYN - TiO (Lyric Video)',
#   'Public': '2018-05-06T07:00:02Z',
#   'Views': '6968584',
#   'Likes': '156627',
#   'Comentarios': '4076'},
#  {'Titulo': 'ZAYN - wRoNg (Lyric Video) ft. Kehlani',
#   'Public': '2018-05-06T07:00:01Z',
#   'Views': '6804481',
#   'Likes': '123908',
#   'Comentarios': '2185'},
#  {'Titulo': 'ZAYN - fOoL fOr YoU (Lyric Video)',
#   'Public': '2018-05-06T07:00:01Z',
#   'Views': '4850128',
#   'Likes': '118615',
#   'Comentarios': '3445'},
#  {'Titulo': 'ZAYN - rEaR vIeW (Lyric Video)',
#   'Public': '2018-05-06T07:00:01Z',
#   'Views': '3296554',
#   'Likes': '63893',
#   'Comentarios': '2126'},
#  {'Titulo': 'ZAYN - sHe (Lyric Video)',
#   'Public': '2018-05-06T07:00:01Z',
#   'Views': '4855888',
#   'Likes': '102562',
#   'Comentarios': '3508'},
#  {'Titulo': 'ZAYN - BRIGHT (Lyric Video)',
#   'Public': '2018-05-06T07:00:01Z',
#   'Views': '761627',
#   'Likes': '33679',
#   'Comentarios': '1209'},
#  {'Titulo': 'ZAYN - tRuTh (Lyric Video)',
#   'Public': '2018-05-06T07:00:01Z',
#   'Views': '1009212',
#   'Likes': '34874',
#   'Comentarios': '1289'},
#  {'Titulo': "ZAYN - SHE DON'T LOVE ME (Lyric Video)",
#   'Public': '2018-05-06T07:00:00Z',
#   'Views': '7863386',
#   'Likes': '147121',
#   'Comentarios': '5025'},
#  {'Titulo': 'ZAYN - Let Me (Official Video)',
#   'Public': '2018-04-12T12:00:04Z',
#   'Views': '189338289',
#   'Likes': '2939169',
#   'Comentarios': '113991'},
#  {'Titulo': 'ZAYN - Dusk Till Dawn (Official Video) ft. Sia',
#   'Public': '2017-09-07T12:00:09Z',
#   'Views': '1809311388',
#   'Likes': '12919131',
#   'Comentarios': '386852'},
#  {'Titulo': 'ZAYN - Dusk Till Dawn Trailer ft. Sia',
#   'Public': '2017-09-06T18:35:34Z',
#   'Views': '2465772',
#   'Likes': '116278',
#   'Comentarios': '3969'},
#  {'Titulo': 'ZAYN - Still Got Time (Official Video) ft. PARTYNEXTDOOR',
#   'Public': '2017-04-21T07:00:05Z',
#   'Views': '69459273',
#   'Likes': '975024',
#   'Comentarios': '29358'},
#  {'Titulo': 'ZAYN - Still Got Time (Lyric) ft. PARTYNEXTDOOR',
#   'Public': '2017-03-23T23:00:01Z',
#   'Views': '25634546',
#   'Likes': '408431',
#   'Comentarios': '15505'},
#  {'Titulo': "I Don't Wanna Live Forever (Fifty Shades Darker) BTS 3 - The Director [EXTENDED]",
#   'Public': '2017-02-01T01:30:01Z',
#   'Views': '1744623',
#   'Likes': '69369',
#   'Comentarios': '1671'},
#  {'Titulo': 'ZAYN, Taylor Swift - I Don’t Wanna Live Forever (Fifty Shades Darker)',
#   'Public': '2017-01-27T05:00:00Z',
#   'Views': '162146605',
#   'Likes': '2046954',
#   'Comentarios': '62201'},
#  {'Titulo': 'ZAYN - LIKE I WOULD (Troyboi Remix) [Audio]',
#   'Public': '2016-05-27T04:01:01Z',
#   'Views': '889434',
#   'Likes': '33748',
#   'Comentarios': '1312'},
#  {'Titulo': 'ZAYN - LIKE I WOULD (Lenno Remix) [Audio]',
#   'Public': '2016-05-27T04:01:01Z',
#   'Views': '588603',
#   'Likes': '24492',
#   'Comentarios': '1149'},
#  {'Titulo': 'ZAYN - LIKE I WOULD (Rytmeklubben Remix) [Audio]',
#   'Public': '2016-05-27T04:01:00Z',
#   'Views': '192500',
#   'Likes': '12439',
#   'Comentarios': '407'},
#  {'Titulo': 'ZAYN - LIKE I WOULD (Oliver Nelson Remix) [Audio]',
#   'Public': '2016-05-27T04:01:00Z',
#   'Views': '367416',
#   'Likes': '15176',
#   'Comentarios': '514'},
#  {'Titulo': 'ZAYN - LIKE I WOULD (Dave Audé Mix) [Audio]',
#   'Public': '2016-05-27T04:01:00Z',
#   'Views': '263959',
#   'Likes': '13711',
#   'Comentarios': '579'},
#  {'Titulo': 'ZAYN - LIKE I WOULD (Sharam Jey Remix) [Audio]',
#   'Public': '2016-05-27T04:01:00Z',
#   'Views': '218169',
#   'Likes': '11509',
#   'Comentarios': '324'},
#  {'Titulo': 'ZAYN - LIKE I WOULD (The White Panda Remix) [Audio]',
#   'Public': '2016-05-13T19:55:49Z',
#   'Views': '1745805',
#   'Likes': '73693',
#   'Comentarios': '3324'},
#  {'Titulo': 'ZAYN - LIKE I WOULD',
#   'Public': '2016-05-10T04:01:00Z',
#   'Views': '80170287',
#   'Likes': '1367592',
#   'Comentarios': '45540'},
#  {'Titulo': 'ZAYN - LIKE I WOULD (Live on the Honda Stage at the iHeartRadio Theater NY)',
#   'Public': '2016-03-29T19:00:01Z',
#   'Views': '5231296',
#   'Likes': '201081',
#   'Comentarios': '6508'},
#  {'Titulo': 'ZAYN - iT’s YoU (Live on the Honda Stage at the iHeartRadio Theater NY)',
#   'Public': '2016-03-29T19:00:00Z',
#   'Views': '10530375',
#   'Likes': '226822',
#   'Comentarios': '9365'},
#  {'Titulo': 'ZAYN - tRuTh (Live on the Honda Stage at the iHeartRadio Theater NY)',
#   'Public': '2016-03-29T19:00:00Z',
#   'Views': '2446626',
#   'Likes': '85737',
#   'Comentarios': '2689'},
#  {'Titulo': "ZAYN - iT's YoU",
#   'Public': '2016-03-28T07:00:00Z',
#   'Views': '52644696',
#   'Likes': '866537',
#   'Comentarios': '35424'},
#  {'Titulo': 'ZAYN - BeFoUr',
#   'Public': '2016-03-25T04:00:00Z',
#   'Views': '58769433',
#   'Likes': '982535',
#   'Comentarios': '40351'},
#  {'Titulo': 'ZAYN - BeFoUr (Audio)',
#   'Public': '2016-03-17T10:00:00Z',
#   'Views': '8645708',
#   'Likes': '228513',
#   'Comentarios': '15577'},
#  {'Titulo': 'ZAYN - LIKE I WOULD (Audio)',
#   'Public': '2016-03-10T11:00:01Z',
#   'Views': '22573401',
#   'Likes': '402812',
#   'Comentarios': '23321'},
#  {'Titulo': 'ZAYN - PILLOWTALK REMIX (Audio) ft. Lil Wayne',
#   'Public': '2016-02-26T23:36:56Z',
#   'Views': '5697194',
#   'Likes': '172716',
#   'Comentarios': '9050'},
#  {'Titulo': "ZAYN - iT's YoU (Audio)",
#   'Public': '2016-02-26T05:01:01Z',
#   'Views': '13319510',
#   'Likes': '332548',
#   'Comentarios': '22399'},
#  {'Titulo': 'ZAYN - PILLOWTALK (the living room session) [Audio]',
#   'Public': '2016-02-05T08:00:00Z',
#   'Views': '3759031',
#   'Likes': '163852',
#   'Comentarios': '7452'},
#  {'Titulo': 'ZAYN - PILLOWTALK (Official Music Video)',
#   'Public': '2016-01-29T05:01:00Z',
#   'Views': '1099532955',
#   'Likes': '8161750',
#   'Comentarios': '472576'}]

# %%
#Le damos estructura de Data Frame:
Detalles_video=detalles_video(youtube,videos_id)
Datos_video=pd.DataFrame(Detalles_video)
Datos_video["Public"]=pd.to_datetime(Datos_video["Public"]).dt.date
Datos_video["Views"]=pd.to_numeric(Datos_video["Views"])
Datos_video["Likes"]=pd.to_numeric(Datos_video["Likes"])
Datos_video["Comentarios"]=pd.to_numeric(Datos_video["Comentarios"])
Datos_video
# Out:
#                                                Titulo      Public       Views  \
# 0                      ZAYN - "River Road" (Comic 11)  2021-03-11      953105
# 1                       ZAYN - "Tightrope" (Comic 10)  2021-03-04      530969
# 2          ZAYN - "Windowsill" feat. Devlin (Comic 9)  2021-03-04      181079
# 3                    ZAYN - "Unf**kwitable" (Comic 8)  2021-02-25      258353
# 4                            ZAYN - "Sweat" (Comic 7)  2021-02-11      371803
# ..                                                ...         ...         ...
# 85                        ZAYN - LIKE I WOULD (Audio)  2016-03-10    22573384
# 86      ZAYN - PILLOWTALK REMIX (Audio) ft. Lil Wayne  2016-02-26     5697187
# 87                            ZAYN - iT's YoU (Audio)  2016-02-26    13319497
# 88  ZAYN - PILLOWTALK (the living room session) [A...  2016-02-05     3759027
# 89           ZAYN - PILLOWTALK (Official Music Video)  2016-01-29  1099530146
#
#       Likes  Comentarios
# 0     62809         3836
# 1     50278         3033
# 2     30499         1988
# 3     46713         3412
# 4     49005         3068
# ..      ...          ...
# 85   402812        23321
# 86   172716         9050
# 87   332547        22399
# 88   163852         7452
# 89  8161724       472577
#
# [90 rows x 5 columns]

# %%
#Top 10 videos más vistos
top_videos=Datos_video.sort_values(by="Views",ascending=False).head(10)
top_videos
# Out:
#                                                Titulo      Public       Views  \
# 65     ZAYN - Dusk Till Dawn (Official Video) ft. Sia  2017-09-07  1809300298
# 89           ZAYN - PILLOWTALK (Official Music Video)  2016-01-29  1099530146
# 64                     ZAYN - Let Me (Official Video)  2018-04-12   189336950
# 70  ZAYN, Taylor Swift - I Don’t Wanna Live Foreve...  2017-01-27   162145499
# 49                ZAYN - Entertainer (Official Video)  2018-05-23    85703682
# 78                                ZAYN - LIKE I WOULD  2016-05-10    80169986
# 67  ZAYN - Still Got Time (Official Video) ft. PAR...  2017-04-21    69459134
# 83                                      ZAYN - BeFoUr  2016-03-25    58769325
# 82                                    ZAYN - iT's YoU  2016-03-28    52644528
# 22                     ZAYN - Better (Official Video)  2020-09-25    39839993
#
#        Likes  Comentarios
# 65  12919032       386850
# 89   8161724       472577
# 64   2939157       113991
# 70   2046942        62201
# 49   1199008        48575
# 78   1367589        45540
# 67    975023        29358
# 83    982532        40351
# 82    866534        35424
# 22   1676978       197944

# %%
#Top 10 videos con más Likes:
top_videos=Datos_video.sort_values(by="Likes",ascending=False).head(10)
top_videos
# Out:
#                                                Titulo      Public       Views  \
# 65     ZAYN - Dusk Till Dawn (Official Video) ft. Sia  2017-09-07  1809300298
# 89           ZAYN - PILLOWTALK (Official Music Video)  2016-01-29  1099530146
# 64                     ZAYN - Let Me (Official Video)  2018-04-12   189336950
# 70  ZAYN, Taylor Swift - I Don’t Wanna Live Foreve...  2017-01-27   162145499
# 22                     ZAYN - Better (Official Video)  2020-09-25    39839993
# 21                      ZAYN - Vibez (Official Video)  2021-01-08    35874199
# 78                                ZAYN - LIKE I WOULD  2016-05-10    80169986
# 49                ZAYN - Entertainer (Official Video)  2018-05-23    85703682
# 83                                      ZAYN - BeFoUr  2016-03-25    58769325
# 67  ZAYN - Still Got Time (Official Video) ft. PAR...  2017-04-21    69459134
#
#        Likes  Comentarios
# 65  12919032       386850
# 89   8161724       472577
# 64   2939157       113991
# 70   2046942        62201
# 22   1676978       197944
# 21   1390380        88888
# 78   1367589        45540
# 49   1199008        48575
# 83    982532        40351
# 67    975023        29358

# %%
#Top 10 videos más comentados:
top_videos=Datos_video.sort_values(by="Comentarios",ascending=False).head(10)
top_videos
# Out:
#                                                Titulo      Public       Views  \
# 89           ZAYN - PILLOWTALK (Official Music Video)  2016-01-29  1099530146
# 65     ZAYN - Dusk Till Dawn (Official Video) ft. Sia  2017-09-07  1809300298
# 22                     ZAYN - Better (Official Video)  2020-09-25    39839993
# 64                     ZAYN - Let Me (Official Video)  2018-04-12   189336950
# 21                      ZAYN - Vibez (Official Video)  2021-01-08    35874199
# 70  ZAYN, Taylor Swift - I Don’t Wanna Live Foreve...  2017-01-27   162145499
# 49                ZAYN - Entertainer (Official Video)  2018-05-23    85703682
# 78                                ZAYN - LIKE I WOULD  2016-05-10    80169986
# 83                                      ZAYN - BeFoUr  2016-03-25    58769325
# 82                                    ZAYN - iT's YoU  2016-03-28    52644528
#
#        Likes  Comentarios
# 89   8161724       472577
# 65  12919032       386850
# 22   1676978       197944
# 64   2939157       113991
# 21   1390380        88888
# 70   2046942        62201
# 49   1199008        48575
# 78   1367589        45540
# 83    982532        40351
# 82    866534        35424
